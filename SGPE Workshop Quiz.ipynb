# %% [markdown]
# # Hello World

# %% [markdown]
# Items to learn today:
# 1. Importing and exporting data in Python
# 2. Data Manipulation (Cleaning)
# 3. Data Analysis

# %% [markdown]
# <font color=blue>**While at it make sure you can also work with the Iris data set and look at the following variabes**:</font>
# * sepal length
# * sepal width
#     - iris dataset

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# You can use this link [SGPE webpage.](https://www.ed.ac.uk/economics/postgraduate/scottish-graduate-programme-economics) to register for classes.

# %% [markdown]
# # Edinburgh

# %%
from IPython.display import Image
Image(filename='edinburgh.jpeg')

# %%
from IPython.display import Image
Image(filename='Network_greenspan.jpg')
